# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show

# %%
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file("text.html")

p = figure(title = "flower")
p.xaxis.axis_label = "petal_lenght"
p.yaxis.axis_label = "petal_width"
p.circle(flowers["petal_length"], flowers["petal_width"])
show(p)
# Out:
#   <div id="d2be7bc8-8dd9-4178-88dd-5bc58460e3c9" data-root-id="p1118" style="display: contents;"></div>

# %%
output_file("text.html")

p = figure(title = "flower")
p.xaxis.axis_label = "petal_lenght"
p.yaxis.axis_label = "petal_width"
p.circle(flowers["petal_length"], flowers["petal_width"])
show(p)

# %%
x=[1,2,3,4,5,6]
y=[2,4,6,8,10,12]
output_file("line.html")

p = figure(title = "line")
p.xaxis.axis_label = "X-axis"
p.yaxis.axis_label = "Y-axis"
p.line(x,y)
show(p)
# Out:
#   <div id="1de634e5-7e0f-4237-b7b3-17b0f4687242" data-root-id="p1743" style="display: contents;"></div>

# %%
x=[1,2,3,4,5,6]
y=[2,4,6,8,10,12]
output_file("line.html")

p = figure(title = "line")
p.xaxis.axis_label = "X-axis"
p.yaxis.axis_label = "Y-axis"
p.circle(x,y, size=10, color="green", legend_label= "Points")
show(p)
# Out:
#   <div id="aba2d910-8094-4c82-9dc1-bccf66e83be4" data-root-id="p2495" style="display: contents;"></div>
