# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone'

# %%
urlclient = urlopen(flipkart_url)

# %%
flipkart_page = urlclient.read()

# %%
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e84a00.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkart_html = bs(flipkart_page, 'html.parser')

# %%
bigbox = flipkart_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 0

# %%
del bigbox[0:3]

# %%
productlink= "https://www.flipkart.com"+ bigbox[0].div.div.div.a["href"]

# %%
for i in bigbox:
    print("https://www.flipkart.com"+ i.div.div.div.a["href"])
# Out:
# https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&lid=LSTMOBGHWFHECFVMDCXBOYSND&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=af567579-54e2-421c-8994-20f062e8b1ee.MOBGHWFHECFVMDCX.SEARCH&ppt=None&ppn=None&ssid=xzg2058qao0000001677035684771&qH=0b3f45b266a97d70
# https://www.flipkart.com/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&lid=LSTMOBGHWFHABH3G73HRLIX56&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=af567579-54e2-421c-8994-20f062e8b1ee.MOBGHWFHABH3G73H.SEARCH&ppt=None&ppn=None&ssid=xzg2058qao0000001677035684771&qH=0b3f45b266a97d70
# ...

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&lid=LSTMOBGHWFHECFVMDCXBOYSND&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=af567579-54e2-421c-8994-20f062e8b1ee.MOBGHWFHECFVMDCX.SEARCH&ppt=None&ppn=None&ssid=xzg2058qao0000001677035684771&qH=0b3f45b266a97d70'

# %%
product_req = requests.get(productlink)
product_req
# Out:
# <Response [200]>

# %%
import requests

response = requests.get(productlink)
if response.ok:
    print('Request was successful')
else:
    print('Request failed')
# Out:
# Request was successful

# %%
import requests

response = requests.get(productlink)
content = response.content
product_html = bs(content, "html.parser")
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment = product_html.find_all("div",{"class":"col _2wzgFH"})

# %%
comment[5].find("div",{"class":"t-ZTKy"}).find("div",{"class":""})
# Out:
# <div><div class="">Happy to have iPhone 14. Wonderful phone specially because of Powerful camera😍, perfect screen size and potentially battery life make it worthy.</div><span class="_1H-bmy"><span>READ MORE</span></span></div>

# %%
comment[5].find("div",{"class":"t-ZTKy"}).find("div",{"class":""}).text
# Out:
# 'Happy to have iPhone 14. Wonderful phone specially because of Powerful camera😍, perfect screen size and potentially battery life make it worthy.READ MORE'

# %%
for i in range(len(comment)):
    print(i, " COMMENTS ARE:\n", comment[i].find("div",{"class":"t-ZTKy"}).find("div",{"class":""}).text)
# Out:
# 0  COMMENTS ARE:
#  Best smart phone under this price range compare to other phones in 2023 if you see overall build quality, performance and Camera with autofocus and video action mode are awesome50% extra RAM compared to iPhone 13 and other more features. Best time to upgrade to iPhone 14 . I am so happy See Low light photos are amazing..READ MORE
# 1  COMMENTS ARE:
#  It's a apple device .. that means you get the good old ios . No performance issue , supper ram and power management . My slightly distasteful remark would be on its camera . Dont get me wrong , its great but the colors seems to be vibrant by default which I'm not really a fan of. Also the low light performance of the front camera is not that sharp . I used to own a pixel 3 and its front camera output seems to be better than iphone 13's . But overall the camera is good and it will do the job. ...READ MORE
# 2  COMMENTS ARE:
# ...

# %%
comment[1].find("div",{"class":"_3LWZlK _1BLPMq"}).text
# Out:
# '4'

# %%
for i in range(len(comment)):
     print(i+1,comment[i].find("div",{"class":"_3LWZlK _1BLPMq"}).text)
# Out:
# 1 5
# 2 4
# 3 5
# 4 5
# 5 5
# 6 5
# 7 5
# 8 4
# 9 5
# 10 5

# %%
for i in range(len(comment)):
    print(comment[1].div.p.text)
# Out:
# Good choice
# Good choice
# Good choice
# Good choice
# Good choice
# Good choice
# Good choice
# Good choice
# Good choice
# Good choice

# %%
# Scrapping Youtube
